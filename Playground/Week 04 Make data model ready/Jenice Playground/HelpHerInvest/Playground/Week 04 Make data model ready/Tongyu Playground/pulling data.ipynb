# %%
import os, subprocess

REPO_URL = "https://github.com/tongyuguo/HelpHerInvest.git"
REPO_DIR = "HelpHerInvest"

def clone_or_pull():
    if os.path.isdir(os.path.join(REPO_DIR, ".git")):
        subprocess.run(["git", "-C", REPO_DIR, "pull"])
    else:
        subprocess.run(["git", "clone", REPO_URL])

clone_or_pull()
# Out:
# Already up to date.

# %%
import pandas as pd
import zipfile

zip_path = "HelpHerInvest/Data/testing_small.csv.zip"

with zipfile.ZipFile(zip_path) as z:
    df = pd.read_csv(z.open("testing_small.csv"))

df.head()
# Out:
#                     address1           city state         zip        country  \
# 0  2788 San Tomas Expressway    Santa Clara    CA       95051  United States
# 1  1600 Amphitheatre Parkway  Mountain View    CA       94043  United States
# 2         One Apple Park Way      Cupertino    CA       95014  United States
# 3          One Microsoft Way        Redmond    WA  98052-6399  United States
# 4     410 Terry Avenue North        Seattle    WA  98109-5210  United States
#
#             phone                    website                        industry  \
# 0    408 486 2000     https://www.nvidia.com                  Semiconductors
# 1    650-253-0000            https://abc.xyz  Internet Content & Information
# 2  (408) 996-1010      https://www.apple.com            Consumer Electronics
# 3    425 882 8080  https://www.microsoft.com       Software - Infrastructure
# 4    206 266 1000     https://www.amazon.com                 Internet Retail
#
#                     industryKey                    industryDisp  ...  \
# 0                semiconductors                  Semiconductors  ...
# 1  internet-content-information  Internet Content & Information  ...
# 2          consumer-electronics            Consumer Electronics  ...
# 3       software-infrastructure       Software - Infrastructure  ...
# 4               internet-retail                 Internet Retail  ...
#
#   fiveYearAverageReturn trailingThreeMonthReturns  \
# 0                   NaN                       NaN
# 1                   NaN                       NaN
# 2                   NaN                       NaN
# 3                   NaN                       NaN
# 4                   NaN                       NaN
#
#   trailingThreeMonthNavReturns netAssets  netExpenseRatio address2  fax  \
# 0                          NaN       NaN              NaN      NaN  NaN
# 1                          NaN       NaN              NaN      NaN  NaN
# 2                          NaN       NaN              NaN      NaN  NaN
# 3                          NaN       NaN              NaN      NaN  NaN
# 4                          NaN       NaN              NaN      NaN  NaN
#
#    industrySymbol  symbol.1    company_name
# 0             NaN      NVDA     NVIDIA CORP
# 1             NaN     GOOGL   Alphabet Inc.
# 2             NaN      AAPL      Apple Inc.
# 3             NaN      MSFT  MICROSOFT CORP
# 4             NaN      AMZN  AMAZON COM INC
#
# [5 rows x 205 columns]

# %%
def can_push():
    result = subprocess.run(
        ["git", "-C", REPO_DIR, "push", "--dry-run"],
        capture_output=True, text=True
    )
    return result.returncode == 0

def commit_and_push(msg="update"):
    subprocess.run(["git", "-C", REPO_DIR, "add", "-A"])
    subprocess.run(["git", "-C", REPO_DIR, "commit", "-m", msg])
    subprocess.run(["git", "-C", REPO_DIR, "push"])

if can_push():
    commit_and_push("update notebook / data")
else:
    print("Not a collaborator — skipping push")
# Out:
# Not a collaborator — skipping push
