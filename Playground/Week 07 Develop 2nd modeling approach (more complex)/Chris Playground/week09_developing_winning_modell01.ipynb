# %% [markdown]
# ## Developing the Winning Model

# %%
import numpy as np
import pandas as pd
#%pip install yfinance
import yfinance as yf
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import zipfile
import requests
warnings.filterwarnings("ignore")

# %%
# Load the data from the zip file

## PATH NEEDS TO BE UPDATED TO GITHUB DATA PATH
zip_path2 = "/Users/christoomey/Desktop/Courses/ADAN8888_Applied_Analytics_Project/Data/final_dataset_20260224v2.csv.zip"
with zipfile.ZipFile(zip_path2) as z:
    df = pd.read_csv(z.open("final_dataset_20260224v2.csv"))

## ## ## ## 

tickers = df["Ticker"].unique()
print(f"Unique tickers in final dataset: {len(tickers)}")
print("Size of dataset:",
"Rows:",df.shape[0],
"Columns:",df.shape[1])
# Out:
# Unique tickers in final dataset: 1993
# Size of dataset: Rows: 302024 Columns: 18

# %%
# count number of positive fwd_excess_return
print("Number of positive fwd_excess_return:", (df["fwd_excess"] > 0).sum())
print("Number of negative fwd_excess_return:", (df["fwd_excess"] < 0).sum())
print("Number of zero fwd_excess_return:", (df["fwd_excess"] == 0).sum())

df = df.copy()

df['y'] = (df['fwd_excess'] > 0).astype(int)
# Out:
# Number of positive fwd_excess_return: 143948
# Number of negative fwd_excess_return: 151730
# Number of zero fwd_excess_return: 287

# %%
# Ensure datetime
df['Date'] = pd.to_datetime(df['Date'])

# Find latest month in dataset
max_date = df['Date'].max()

# Compute cutoff
cutoff_date = max_date - pd.DateOffset(months=2)

# Subset
df_last3 = df[df['Date'] > cutoff_date].copy()
df_last3.head()
# Out:
#              Date Ticker  mom_1m  mom_3m  mom_6m  mom_12m  mom_12m_ex_1m  \
# 296052 2025-12-31   NVDA  0.4632 -0.1615 -0.0187  -0.0007        -0.0109
# 296053 2025-12-31  GOOGL -0.2588  0.9727  0.2777   0.0626         0.1162
# 296054 2025-12-31   AAPL -0.2902  0.1099  0.0543  -0.0705        -0.0779
# 296055 2025-12-31   MSFT -0.2136 -0.4135 -0.1202  -0.0553        -0.0587
# 296056 2025-12-31   AMZN -0.1489  0.0413 -0.0823  -0.0795        -0.0966
#
#         rel_3m_spy  rel_6m_spy  rel_12m_spy  vol_3m  vol_6m  drawdown_6m  \
# 296052     -0.1615     -0.0187      -0.0007 -0.0587 -0.1146       0.0987
# 296053      0.9727      0.2777       0.0626 -0.2683 -0.1787       0.6149
# 296054      0.1099      0.0543      -0.0705 -0.6517 -0.2838       0.5852
# 296055     -0.4135     -0.1202      -0.0553 -0.6087 -0.3388      -0.0043
# 296056      0.0413     -0.0823      -0.0795 -0.1768 -0.1408       0.3160
#
#         drawdown_12m  pct_above_200dma  adj_close  fwd_excess  fwd_return  y
# 296052        0.3188            0.2869   186.5000         NaN         NaN  0
# 296053        0.7311            1.4220   313.0000         NaN         NaN  0
# 296054        0.7074            0.3279   271.6058         NaN         NaN  0
# 296055        0.2366           -0.3248   482.5187         NaN         NaN  0
# 296056        0.4923           -0.1244   230.8200         NaN         NaN  0

# %% [markdown]
# ### Split the Data 70/15/15

# %%
def time_split(df, date_col='Date', train_frac=0.7, val_frac=0.15):
    df = df.sort_values(date_col).copy()
    unique_dates = df[date_col].drop_duplicates().sort_values().to_numpy()

    # retreive the num of rows to create train/val/test split
    n = len(unique_dates)
    train_end = int(n * train_frac)
    val_end = int(n * (train_frac + val_frac))

    train_dates = unique_dates[:train_end]
    val_dates   = unique_dates[train_end:val_end]
    test_dates  = unique_dates[val_end:]

    train = df[df[date_col].isin(train_dates)]
    val   = df[df[date_col].isin(val_dates)]
    test  = df[df[date_col].isin(test_dates)]

    return train, val, test

training_data, validation_data, testing_data = time_split(df)
print("Train size:", training_data.shape)
print("Val size:", validation_data.shape)
print("Test size:", testing_data.shape)
training_data.tail()
# Out:
# Train size: (193638, 19)
# Val size: (52704, 19)
# Test size: (55682, 19)
#              Date Ticker  mom_1m  mom_3m  mom_6m  mom_12m  mom_12m_ex_1m  \
# 192479 2021-04-30   SSNC  0.2723  0.1806 -0.0387  -0.1580        -0.1615
# 192485 2021-04-30     LH  0.0402  0.0731 -0.0345  -0.0866        -0.0872
# 192486 2021-04-30    IHG -0.0824  0.0408 -0.0311  -0.1020        -0.0977
# 192487 2021-04-30    CHD -0.6758 -0.6346 -0.0551  -0.1904        -0.1656
# 192484 2021-04-30    NVR  0.3069 -0.0899 -0.0381  -0.0860        -0.0957
#
#         rel_3m_spy  rel_6m_spy  rel_12m_spy  vol_3m  vol_6m  drawdown_6m  \
# 192479      0.1806     -0.0387      -0.1580 -0.5679 -0.0456       0.5045
# 192485      0.0731     -0.0345      -0.0866 -0.5906 -0.0432       0.5045
# 192486      0.0408     -0.0311      -0.1020 -0.3594 -0.0339       0.5045
# 192487     -0.6346     -0.0551      -0.1904 -0.7487 -0.0506       0.2809
# 192484     -0.0899     -0.0381      -0.0860 -0.4088 -0.0409       0.5045
#
#         drawdown_12m  pct_above_200dma  adj_close  fwd_excess  fwd_return  y
# 192479        0.5021           -0.3760    69.7704      0.0042      0.0585  1
# 192485        0.5021            0.2354   218.1971      0.0596      0.1139  1
# 192486        0.5021           -0.2273    65.4198     -0.1253     -0.0710  0
# 192487       -0.5392           -1.1342    80.8025     -0.0415      0.0127  0
# 192484        0.5021           -0.1548  5018.1001     -0.0135      0.0408  0

# %% [markdown]
# ### Preprocess the Data

# %%
def preprocess_data(df):

    # preprocess the data by dropping rows with missing values
    print("Missing fwd_excess values:")

    df_dropped = df.dropna()
    print("---  ---  ---")
    print("Length of original:",len(df.index))
    print("Length of dropped:",len(df_dropped.index))
    print("Sanity check - missing fwd_excess values after dropping:")
    print(df_dropped[["Date","Ticker","fwd_excess"]].tail(5)) 

   
    
    # Create log_adj_close column
    df_dropped["log_adj_close"] = np.log(df_dropped["adj_close"])
    df_dropped[["adj_close","log_adj_close"]].hist(figsize=(14, 10), bins=50)
    plt.tight_layout()
    plt.show()
    
    return df_dropped

# %%
train_df = preprocess_data(training_data)
train_df.head(5)
# Out:
# Missing fwd_excess values:
# ---  ---  ---
# Length of original: 193638
# Length of dropped: 175057
# Sanity check - missing fwd_excess values after dropping:
#              Date Ticker  fwd_excess
# 192479 2021-04-30   SSNC      0.0042
# 192485 2021-04-30     LH      0.0596
# 192486 2021-04-30    IHG     -0.1253
# 192487 2021-04-30    CHD     -0.0415
# 192484 2021-04-30    NVR     -0.0135
#             Date Ticker  mom_1m  mom_3m  mom_6m  mom_12m  mom_12m_ex_1m  \
# 14213 2011-01-31   TTMI  0.4972  2.4448  1.1222   0.4989         0.3268
# 14216 2011-01-31   DSGX -0.2733 -0.0527 -0.1622  -0.4035        -0.3472
# 14215 2011-01-31   CHDN -0.6391  0.2684 -0.2432  -0.4573        -0.2885
# 14214 2011-01-31   GSAT -0.9448 -1.6521 -1.5770   0.1845         0.5515
# 14218 2011-01-31   MASI  0.1469 -0.5690  0.3651  -0.3740        -0.4427
#
#        rel_3m_spy  rel_6m_spy  rel_12m_spy  vol_3m  vol_6m  drawdown_6m  \
# 14213      2.4448      1.1222       0.4989  1.9380  1.5628       0.5788
# 14216     -0.0527     -0.1622      -0.4035 -0.1112 -0.1488       0.4071
# 14215      0.2684     -0.2432      -0.4573 -0.2997 -0.2583      -0.2127
# 14214     -1.6521     -1.5770       0.1845  0.8672  1.1957      -3.3892
# 14218     -0.5690      0.3651      -0.3740  0.1033 -0.0491       0.4829
#
#        drawdown_12m  pct_above_200dma  adj_close  fwd_excess  fwd_return  y  \
# 14213        0.5941            1.7258    15.9000      0.1377      0.2025  1
# 14216        0.4935           -0.0843     6.9700     -0.1136     -0.0488  0
# 14215        0.1302           -0.0399     6.2609     -0.0576      0.0072  0
# 14214       -2.4986           -1.9339    20.1000     -0.1021     -0.0373  0
# 14218        0.5379            0.1353    28.5698      0.0956      0.1604  1
#
#        log_adj_close
# 14213       2.766319
# 14216       1.941615
# 14215       1.834324
# 14214       3.000720
# 14218       3.352350

# %%
test_df = preprocess_data(testing_data)
test_df.head(5)
# Out:
# Missing fwd_excess values:
# ---  ---  ---
# Length of original: 55682
# Length of dropped: 48493
# Sanity check - missing fwd_excess values after dropping:
#              Date Ticker  fwd_excess
# 294730 2025-11-30    GPN      0.0285
# 294731 2025-11-30   BURL      0.2126
# 294732 2025-11-30   KTOS      0.1828
# 294733 2025-11-30   TRMB     -0.1891
# 294728 2025-11-30   SBAC      0.0290
#              Date Ticker  mom_1m  mom_3m  mom_6m  mom_12m  mom_12m_ex_1m  \
# 247583 2023-10-31   MNSO  0.2820  1.8365  1.5085  10.5307        10.4558
# 247584 2023-10-31    ACT  0.6388  0.7340  0.6076   0.1936         0.0074
# 247585 2023-10-31   ZETA -0.1585 -0.1970 -0.7219  -0.3790        -0.3453
# 247586 2023-10-31    RHP  0.7997  0.1445 -0.0652  -0.2143        -0.4258
# 247592 2023-10-31    ARW -0.4508 -0.4682 -0.0130   0.1119         0.2669
#
#         rel_3m_spy  rel_6m_spy  rel_12m_spy  vol_3m  vol_6m  drawdown_6m  \
# 247583      1.8365      1.5085      10.5307  0.8386  0.7170       1.0479
# 247584      0.7340      0.6076       0.1936 -0.5861 -0.4127       0.9323
# 247585     -0.1970     -0.7219      -0.3790  0.8372  0.4462       0.0756
# 247586      0.1445     -0.0652      -0.2143 -0.3047 -0.3832       0.5455
# 247592     -0.4682     -0.0130       0.1119 -0.2618 -0.3952      -0.3258
#
#         drawdown_12m  pct_above_200dma  adj_close  fwd_excess  fwd_return  y  \
# 247583        1.1475            2.2729    24.0159     -0.4893     -0.3299  0
# 247584        1.0483            0.8457    25.5351     -0.0930      0.0664  0
# 247585       -0.4865           -0.4454     7.8000      0.0817      0.2410  1
# 247586        0.7163            0.1875    77.3804      0.1373      0.2966  1
# 247592       -0.0314           -0.2352   113.4100     -0.1793     -0.0199  0
#
#         log_adj_close
# 247583       3.178716
# 247584       3.240054
# 247585       2.054124
# 247586       4.348734
# 247592       4.731010

# %%
val_df = preprocess_data(validation_data)
val_df.head(5)
# Out:
# Missing fwd_excess values:
# ---  ---  ---
# Length of original: 52704
# Length of dropped: 50961
# Sanity check - missing fwd_excess values after dropping:
#              Date Ticker  fwd_excess
# 245100 2023-09-30    HPQ      0.0652
# 245099 2023-09-30    PFG     -0.0149
# 245098 2023-09-30   TWLO      0.1799
# 245097 2023-09-30   CHRW     -0.1058
# 245108 2023-09-30    RCI      0.1129
#              Date Ticker  mom_1m  mom_3m  mom_6m  mom_12m  mom_12m_ex_1m  \
# 194796 2021-05-31   SITE -0.6464 -0.0770 -0.0860  -0.0469        -0.0277
# 194804 2021-05-31    DLB -0.6009 -0.5411 -0.3627  -0.0460        -0.0284
# 194803 2021-05-31      M  0.8177  0.5672  1.0082   0.2009         0.1754
# 194805 2021-05-31   TRNO -0.3711  0.2303 -0.3603  -0.1159        -0.1162
# 194802 2021-05-31    DAR -0.3743 -0.0735  0.2600   0.2133         0.2577
#
#         rel_3m_spy  rel_6m_spy  rel_12m_spy  vol_3m  vol_6m  drawdown_6m  \
# 194796     -0.0770     -0.0860      -0.0469  0.2931  0.1085       0.1177
# 194804     -0.5411     -0.3627      -0.0460 -0.5613 -0.5965       0.1629
# 194803      0.5672      1.0082       0.2009  1.2113  1.2406       0.5328
# 194805      0.2303     -0.3603      -0.1159 -0.6730 -0.6928       0.3913
# 194802     -0.0735      0.2600       0.2133  0.4512  0.3094      -0.1731
#
#         drawdown_12m  pct_above_200dma  adj_close  fwd_excess  fwd_return  y  \
# 194796        0.1482           -0.2446   172.0400      0.0845      0.1631  1
# 194804        0.1910           -0.3061    90.8153     -0.0602      0.0184  0
# 194803        0.5413            1.7165    15.3682      0.1463      0.2248  1
# 194805        0.4073           -0.4687    55.7725     -0.0238      0.0548  0
# 194802       -0.1272            0.1532    68.4600      0.0097      0.0882  1
#
#         log_adj_close
# 194796       5.147727
# 194804       4.508828
# 194803       2.732300
# 194805       4.021281
# 194802       4.226250

# %% [markdown]
# ### Create the Train, Validation, and Test sets

# %%
feature_cols = [col for col in train_df.columns if col not in ["Date", "Ticker", "fwd_excess", "fwd_return", "y"]]

X_train, y_train = train_df[feature_cols], train_df['y']
X_val, y_val     = val_df[feature_cols],   val_df['y']
X_test, y_test   = test_df[feature_cols],  test_df['y']

# %% [markdown]
# ### Logistic Regression Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import numpy as np

# L1 (Lasso) Logistic Regression

log_reg = Pipeline([
    ('scaler', StandardScaler()),
    ('logit', LogisticRegression(
        penalty='l1',
        solver='saga',
        max_iter=1000
    ))
])

log_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('logit',
#                  LogisticRegression(max_iter=1000, penalty='l1',
#                                     solver='saga'))])

# %%
# Elastic Net Logistic Regression 

elastic_net = Pipeline([
    ('scaler', StandardScaler()),
    ('logit', LogisticRegression(
        penalty='elasticnet',
        solver='saga',
        l1_ratio=0.5,   # 50% L1 / 50% L2
        max_iter=1000
    ))
])

elastic_net.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('logit',
#                  LogisticRegression(l1_ratio=0.5, max_iter=1000,
#                                     penalty='elasticnet', solver='saga'))])

# %%
# Weighted Logistic Regression

weight_log_reg = Pipeline([
    ('scaler', StandardScaler()),
    ('logit', LogisticRegression(
        class_weight='balanced',
        max_iter=500
    ))
])

weight_log_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('logit',
#                  LogisticRegression(class_weight='balanced', max_iter=500))])

# %% [markdown]
# ### Light Gradient Boosting Machine (LightGBM) Models

# %%
# LightGBM Model 1 with more conservative hyperparameters

import lightgbm as lgb

lgb_model1 = lgb.LGBMClassifier(
    n_estimators=1000,
    learning_rate=0.01,
    max_depth=6,
    num_leaves=31
)

lgb_model1.fit(
    X_train,
    y_train,
    eval_set=[(X_val, y_val)],

)
# Out:
# [LightGBM] [Info] Number of positive: 86255, number of negative: 88802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002002 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3825
# [LightGBM] [Info] Number of data points in the train set: 175057, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.492725 -> initscore=-0.029101
# [LightGBM] [Info] Start training from score -0.029101
# LGBMClassifier(learning_rate=0.01, max_depth=6, n_estimators=1000)

# %%
# LightGBM Model 2 with more aggressive hyperparameters

lgb_model2 = lgb.LGBMClassifier(
    n_estimators=1000,
    learning_rate=0.01,
    max_depth=12,
    num_leaves=31,
    class_weight="balanced",    
)

lgb_model2.fit(
    X_train,
    y_train,
    eval_set=[(X_val, y_val)],

)
# Out:
# [LightGBM] [Info] Number of positive: 86255, number of negative: 88802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001695 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3825
# [LightGBM] [Info] Number of data points in the train set: 175057, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# LGBMClassifier(class_weight='balanced', learning_rate=0.01, max_depth=12,
#                n_estimators=1000)

# %%
# LightGBM Model 3 with even more aggressive hyperparameters

lgb_model3 = lgb.LGBMClassifier(
    n_estimators=500,
    learning_rate=0.01, 
    max_depth=6,
    num_leaves=20
)

lgb_model3.fit(
    X_train,
    y_train,
    eval_set=[(X_val, y_val)],

)
# Out:
# [LightGBM] [Info] Number of positive: 86255, number of negative: 88802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001525 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3825
# [LightGBM] [Info] Number of data points in the train set: 175057, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.492725 -> initscore=-0.029101
# [LightGBM] [Info] Start training from score -0.029101
# LGBMClassifier(learning_rate=0.01, max_depth=6, n_estimators=500, num_leaves=20)

# %% [markdown]
# ### Neural Network Models

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks, regularizers
from sklearn.utils.class_weight import compute_class_weight

SEED = 42
tf.random.set_seed(SEED)

# %%
'''
X_train, y_train = train_df[feature_cols], train_df['y']
X_val, y_val     = val_df[feature_cols],   val_df['y']
X_test, y_test   = test_df[feature_cols],  test_df['y']
'''
X_train_nn = X_train.values
y_train_nn = y_train.values
X_val_nn = X_val.values
y_val_nn = y_val.values
X_test_nn = X_test.values
y_test_nn = y_test.values

scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train_nn)
X_val_s = scaler.transform(X_val_nn)
X_test_s = scaler.transform(X_test_nn)

# %%
# Class weights for imbalance
classes = np.unique(y_train_nn)
weights = compute_class_weight(class_weight="balanced", classes=classes, y=y_train_nn)
class_weight = dict(zip(classes, weights))
class_weight
# Out:
# {0: 0.9856591067768744, 1: 1.0147643614862907}

# %%
early_stop = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=4,
    min_lr=1e-5
)

# %%
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    classification_report,
    roc_auc_score,
    confusion_matrix
)

def evaluate_model(model, X, y, name="Model"):
    prob = model.predict(X, verbose=0).ravel()
    pred = (prob >= 0.5).astype(int)

    print(f"\n{name}")
    print("Accuracy:", round(accuracy_score(y, pred), 4))
    print("F1:", round(f1_score(y_test, pred, average='macro'), 4))
    print("ROC AUC:", round(roc_auc_score(y, prob), 4))
    print("\nConfusion Matrix")
    print(confusion_matrix(y, pred))
    print("\nClassification Report")
    print(classification_report(y, pred, digits=4))

# %%
def build_mlp_baseline(input_dim):
    model = keras.Sequential([
        layers.Input(shape=(input_dim,)),
        layers.Dense(64, activation="relu"),
        layers.Dropout(0.2),
        layers.Dense(32, activation="relu"),
        layers.Dropout(0.2),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=[
            keras.metrics.BinaryAccuracy(name="accuracy"),
            keras.metrics.AUC(name="auc")
        ]
    )
    return model

model_base = build_mlp_baseline(X_train_s.shape[1])

history_base = model_base.fit(
    X_train_s, y_train,
    validation_data=(X_val_s, y_val),
    epochs=100,
    batch_size=256,
    class_weight=class_weight,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

evaluate_model(model_base, X_test_s, y_test, name="Variation A: Baseline MLP")
# Out:
# Epoch 1/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.5105 - auc: 0.5143 - loss: 0.6946 - val_accuracy: 0.4993 - val_auc: 0.5047 - val_loss: 0.6936 - learning_rate: 0.0010
# Epoch 2/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5134 - auc: 0.5202 - loss: 0.6924 - val_accuracy: 0.4937 - val_auc: 0.5019 - val_loss: 0.6941 - learning_rate: 0.0010
# Epoch 3/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 932us/step - accuracy: 0.5148 - auc: 0.5234 - loss: 0.6921 - val_accuracy: 0.4928 - val_auc: 0.5013 - val_loss: 0.6943 - learning_rate: 0.0010
# Epoch 4/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5180 - auc: 0.5269 - loss: 0.6917 - val_accuracy: 0.4985 - val_auc: 0.5057 - val_loss: 0.6943 - learning_rate: 0.0010
# Epoch 5/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5200 - auc: 0.5296 - loss: 0.6914 - val_accuracy: 0.4960 - val_auc: 0.5040 - val_loss: 0.6946 - learning_rate: 0.0010
# Epoch 6/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5214 - auc: 0.5330 - loss: 0.6909 - val_accuracy: 0.4968 - val_auc: 0.5049 - val_loss: 0.6947 - learning_rate: 5.0000e-04
# Epoch 7/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5210 - auc: 0.5320 - loss: 0.6910 - val_accuracy: 0.4941 - val_auc: 0.5020 - val_loss: 0.6949 - learning_rate: 5.0000e-04
# Epoch 8/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 934us/step - accuracy: 0.5213 - auc: 0.5352 - loss: 0.6906 - val_accuracy: 0.4952 - val_auc: 0.5037 - val_loss: 0.6950 - learning_rate: 5.0000e-04
# Epoch 9/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 870us/step - accuracy: 0.5237 - auc: 0.5374 - loss: 0.6904 - val_accuracy: 0.4952 - val_auc: 0.5020 - val_loss: 0.6953 - learning_rate: 5.0000e-04
# Epoch 10/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5254 - auc: 0.5383 - loss: 0.6902 - val_accuracy: 0.4982 - val_auc: 0.5022 - val_loss: 0.6951 - learning_rate: 2.5000e-04
# Epoch 11/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 868us/step - accuracy: 0.5251 - auc: 0.5384 - loss: 0.6901 - val_accuracy: 0.4975 - val_auc: 0.5047 - val_loss: 0.6950 - learning_rate: 2.5000e-04
# Epoch 12/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 875us/step - accuracy: 0.5234 - auc: 0.5384 - loss: 0.6901 - val_accuracy: 0.4979 - val_auc: 0.5040 - val_loss: 0.6952 - learning_rate: 2.5000e-04
# Epoch 13/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 865us/step - accuracy: 0.5249 - auc: 0.5382 - loss: 0.6901 - val_accuracy: 0.4970 - val_auc: 0.5046 - val_loss: 0.6951 - learning_rate: 2.5000e-04
# Epoch 14/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 865us/step - accuracy: 0.5258 - auc: 0.5408 - loss: 0.6898 - val_accuracy: 0.4997 - val_auc: 0.5039 - val_loss: 0.6951 - learning_rate: 1.2500e-04
# Epoch 15/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 874us/step - accuracy: 0.5258 - auc: 0.5404 - loss: 0.6899 - val_accuracy: 0.4988 - val_auc: 0.5045 - val_loss: 0.6951 - learning_rate: 1.2500e-04
# Epoch 16/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5266 - auc: 0.5419 - loss: 0.6897 - val_accuracy: 0.4991 - val_auc: 0.5043 - val_loss: 0.6952 - learning_rate: 1.2500e-04
# Epoch 17/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5273 - auc: 0.5415 - loss: 0.6897 - val_accuracy: 0.4992 - val_auc: 0.5044 - val_loss: 0.6952 - learning_rate: 1.2500e-04
# Epoch 18/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 869us/step - accuracy: 0.5269 - auc: 0.5414 - loss: 0.6898 - val_accuracy: 0.5000 - val_auc: 0.5045 - val_loss: 0.6951 - learning_rate: 6.2500e-05
# Epoch 19/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 865us/step - accuracy: 0.5277 - auc: 0.5418 - loss: 0.6897 - val_accuracy: 0.5003 - val_auc: 0.5046 - val_loss: 0.6951 - learning_rate: 6.2500e-05
# Epoch 20/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 870us/step - accuracy: 0.5267 - auc: 0.5415 - loss: 0.6896 - val_accuracy: 0.5006 - val_auc: 0.5043 - val_loss: 0.6952 - learning_rate: 6.2500e-05
# Epoch 21/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5285 - auc: 0.5429 - loss: 0.6895 - val_accuracy: 0.5003 - val_auc: 0.5041 - val_loss: 0.6953 - learning_rate: 6.2500e-05
#
# Variation A: Baseline MLP
# Accuracy: 0.5148
# F1: 0.5099
# ROC AUC: 0.5358
#
# Confusion Matrix
# [[10051 15841]
#  [ 7686 14915]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0     0.5667    0.3882    0.4607     25892
#            1     0.4849    0.6599    0.5591     22601
#
#     accuracy                         0.5148     48493
#    macro avg     0.5258    0.5241    0.5099     48493
# weighted avg     0.5286    0.5148    0.5066     48493

# %%
def build_mlp_regularized(input_dim):
    l2 = regularizers.l2(1e-4)

    inputs = keras.Input(shape=(input_dim,))
    x = layers.Dense(256, kernel_regularizer=l2)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.35)(x)

    x = layers.Dense(128, kernel_regularizer=l2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.30)(x)

    x = layers.Dense(64, kernel_regularizer=l2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.20)(x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs, outputs)
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=5e-4),
        loss="binary_crossentropy",
        metrics=[
            keras.metrics.BinaryAccuracy(name="accuracy"),
            keras.metrics.AUC(name="auc")
        ]
    )
    return model

model_reg = build_mlp_regularized(X_train_s.shape[1])

history_reg = model_reg.fit(
    X_train_s, y_train,
    validation_data=(X_val_s, y_val),
    epochs=100,
    batch_size=256,
    class_weight=class_weight,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

evaluate_model(model_reg, X_test_s, y_test, name="Variation B: Regularized MLP")
# Out:
# Epoch 1/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5037 - auc: 0.5058 - loss: 0.7410 - val_accuracy: 0.4919 - val_auc: 0.4992 - val_loss: 0.7222 - learning_rate: 5.0000e-04
# Epoch 2/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5071 - auc: 0.5096 - loss: 0.7220 - val_accuracy: 0.4962 - val_auc: 0.4944 - val_loss: 0.7183 - learning_rate: 5.0000e-04
# Epoch 3/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5105 - auc: 0.5164 - loss: 0.7157 - val_accuracy: 0.4944 - val_auc: 0.4966 - val_loss: 0.7145 - learning_rate: 5.0000e-04
# Epoch 4/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5130 - auc: 0.5195 - loss: 0.7110 - val_accuracy: 0.4918 - val_auc: 0.4968 - val_loss: 0.7106 - learning_rate: 5.0000e-04
# Epoch 5/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5145 - auc: 0.5215 - loss: 0.7079 - val_accuracy: 0.4927 - val_auc: 0.5007 - val_loss: 0.7087 - learning_rate: 2.5000e-04
# Epoch 6/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5173 - auc: 0.5260 - loss: 0.7054 - val_accuracy: 0.4943 - val_auc: 0.4978 - val_loss: 0.7069 - learning_rate: 2.5000e-04
# Epoch 7/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5202 - auc: 0.5292 - loss: 0.7031 - val_accuracy: 0.4911 - val_auc: 0.4989 - val_loss: 0.7058 - learning_rate: 2.5000e-04
# Epoch 8/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5188 - auc: 0.5294 - loss: 0.7013 - val_accuracy: 0.4973 - val_auc: 0.4977 - val_loss: 0.7039 - learning_rate: 2.5000e-04
# Epoch 9/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5222 - auc: 0.5338 - loss: 0.6997 - val_accuracy: 0.4969 - val_auc: 0.5010 - val_loss: 0.7032 - learning_rate: 1.2500e-04
# Epoch 10/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5223 - auc: 0.5333 - loss: 0.6991 - val_accuracy: 0.4967 - val_auc: 0.5000 - val_loss: 0.7028 - learning_rate: 1.2500e-04
# Epoch 11/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5237 - auc: 0.5364 - loss: 0.6981 - val_accuracy: 0.4981 - val_auc: 0.5008 - val_loss: 0.7020 - learning_rate: 1.2500e-04
# Epoch 12/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5261 - auc: 0.5383 - loss: 0.6973 - val_accuracy: 0.4984 - val_auc: 0.5020 - val_loss: 0.7017 - learning_rate: 1.2500e-04
# Epoch 13/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5272 - auc: 0.5402 - loss: 0.6967 - val_accuracy: 0.4996 - val_auc: 0.5007 - val_loss: 0.7015 - learning_rate: 6.2500e-05
# Epoch 14/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5291 - auc: 0.5420 - loss: 0.6964 - val_accuracy: 0.5011 - val_auc: 0.5023 - val_loss: 0.7011 - learning_rate: 6.2500e-05
# Epoch 15/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5276 - auc: 0.5415 - loss: 0.6962 - val_accuracy: 0.5016 - val_auc: 0.5030 - val_loss: 0.7008 - learning_rate: 6.2500e-05
# Epoch 16/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5295 - auc: 0.5444 - loss: 0.6955 - val_accuracy: 0.4994 - val_auc: 0.5002 - val_loss: 0.7013 - learning_rate: 6.2500e-05
# Epoch 17/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5291 - auc: 0.5433 - loss: 0.6955 - val_accuracy: 0.5006 - val_auc: 0.5008 - val_loss: 0.7009 - learning_rate: 3.1250e-05
# Epoch 18/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5290 - auc: 0.5439 - loss: 0.6953 - val_accuracy: 0.5009 - val_auc: 0.5002 - val_loss: 0.7009 - learning_rate: 3.1250e-05
# Epoch 19/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5298 - auc: 0.5448 - loss: 0.6952 - val_accuracy: 0.4995 - val_auc: 0.5003 - val_loss: 0.7008 - learning_rate: 3.1250e-05
# Epoch 20/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5318 - auc: 0.5469 - loss: 0.6948 - val_accuracy: 0.5000 - val_auc: 0.5010 - val_loss: 0.7008 - learning_rate: 3.1250e-05
#
# Variation B: Regularized MLP
# Accuracy: 0.5117
# F1: 0.5041
# ROC AUC: 0.5344
#
# Confusion Matrix
# [[ 9415 16477]
#  [ 7203 15398]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0     0.5666    0.3636    0.4430     25892
#            1     0.4831    0.6813    0.5653     22601
#
#     accuracy                         0.5117     48493
#    macro avg     0.5248    0.5225    0.5041     48493
# weighted avg     0.5276    0.5117    0.5000     48493

# %%
def build_mlp_regularized_deep(input_dim):
    l2 = regularizers.l2(1e-4)

    inputs = keras.Input(shape=(input_dim,))
    x = layers.Dense(256, kernel_regularizer=l2)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.35)(x)

    x = layers.Dense(128, kernel_regularizer=l2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.30)(x)

    x = layers.Dense(64, kernel_regularizer=l2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.10)(x)

    x = layers.Dense(32, kernel_regularizer=l2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.05)(x)

    x = layers.Dense(16, kernel_regularizer=l2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs, outputs)
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=5e-4),
        loss="binary_crossentropy",
        metrics=[
            keras.metrics.BinaryAccuracy(name="accuracy"),
            keras.metrics.AUC(name="auc")
        ]
    )
    return model

model_reg_deep = build_mlp_regularized_deep(X_train_s.shape[1])

history_reg_deep = model_reg_deep.fit(
    X_train_s, y_train,
    validation_data=(X_val_s, y_val),
    epochs=100,
    batch_size=256,
    class_weight=class_weight,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

evaluate_model(model_reg_deep, X_test_s, y_test, name="Variation C: Deep Regularized MLP")
# Out:
# Epoch 1/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5016 - auc: 0.5045 - loss: 0.7318 - val_accuracy: 0.5012 - val_auc: 0.4995 - val_loss: 0.7245 - learning_rate: 5.0000e-04
# Epoch 2/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5099 - auc: 0.5139 - loss: 0.7219 - val_accuracy: 0.4874 - val_auc: 0.4926 - val_loss: 0.7206 - learning_rate: 5.0000e-04
# Epoch 3/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5120 - auc: 0.5192 - loss: 0.7162 - val_accuracy: 0.4807 - val_auc: 0.4903 - val_loss: 0.7160 - learning_rate: 5.0000e-04
# Epoch 4/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5156 - auc: 0.5239 - loss: 0.7110 - val_accuracy: 0.4886 - val_auc: 0.4975 - val_loss: 0.7111 - learning_rate: 5.0000e-04
# Epoch 5/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5152 - auc: 0.5255 - loss: 0.7074 - val_accuracy: 0.4858 - val_auc: 0.4919 - val_loss: 0.7093 - learning_rate: 2.5000e-04
# Epoch 6/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5192 - auc: 0.5302 - loss: 0.7051 - val_accuracy: 0.4908 - val_auc: 0.4962 - val_loss: 0.7075 - learning_rate: 2.5000e-04
# Epoch 7/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5212 - auc: 0.5324 - loss: 0.7031 - val_accuracy: 0.4918 - val_auc: 0.4925 - val_loss: 0.7061 - learning_rate: 2.5000e-04
# Epoch 8/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5215 - auc: 0.5324 - loss: 0.7016 - val_accuracy: 0.4933 - val_auc: 0.4924 - val_loss: 0.7048 - learning_rate: 2.5000e-04
# Epoch 9/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5250 - auc: 0.5381 - loss: 0.6999 - val_accuracy: 0.4938 - val_auc: 0.4947 - val_loss: 0.7044 - learning_rate: 1.2500e-04
# Epoch 10/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5247 - auc: 0.5377 - loss: 0.6993 - val_accuracy: 0.4942 - val_auc: 0.4936 - val_loss: 0.7044 - learning_rate: 1.2500e-04
# Epoch 11/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5270 - auc: 0.5406 - loss: 0.6984 - val_accuracy: 0.4960 - val_auc: 0.4942 - val_loss: 0.7039 - learning_rate: 1.2500e-04
# Epoch 12/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5269 - auc: 0.5412 - loss: 0.6979 - val_accuracy: 0.4974 - val_auc: 0.4950 - val_loss: 0.7034 - learning_rate: 1.2500e-04
# Epoch 13/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5288 - auc: 0.5429 - loss: 0.6974 - val_accuracy: 0.4961 - val_auc: 0.4956 - val_loss: 0.7033 - learning_rate: 6.2500e-05
# Epoch 14/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5288 - auc: 0.5435 - loss: 0.6971 - val_accuracy: 0.4973 - val_auc: 0.4969 - val_loss: 0.7031 - learning_rate: 6.2500e-05
# Epoch 15/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5296 - auc: 0.5432 - loss: 0.6968 - val_accuracy: 0.4974 - val_auc: 0.4961 - val_loss: 0.7030 - learning_rate: 6.2500e-05
# Epoch 16/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5300 - auc: 0.5445 - loss: 0.6965 - val_accuracy: 0.4951 - val_auc: 0.4945 - val_loss: 0.7034 - learning_rate: 6.2500e-05
# Epoch 17/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5323 - auc: 0.5470 - loss: 0.6961 - val_accuracy: 0.4954 - val_auc: 0.4953 - val_loss: 0.7032 - learning_rate: 3.1250e-05
# Epoch 18/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5321 - auc: 0.5475 - loss: 0.6959 - val_accuracy: 0.4963 - val_auc: 0.4956 - val_loss: 0.7032 - learning_rate: 3.1250e-05
# Epoch 19/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5339 - auc: 0.5477 - loss: 0.6959 - val_accuracy: 0.4958 - val_auc: 0.4947 - val_loss: 0.7033 - learning_rate: 3.1250e-05
# Epoch 20/100
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5347 - auc: 0.5494 - loss: 0.6956 - val_accuracy: 0.4970 - val_auc: 0.4945 - val_loss: 0.7034 - learning_rate: 3.1250e-05
#
# Variation C: Deep Regularized MLP
# Accuracy: 0.5202
# F1: 0.5188
# ROC AUC: 0.5274
#
# Confusion Matrix
# [[13932 11960]
#  [11305 11296]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0     0.5520    0.5381    0.5450     25892
#            1     0.4857    0.4998    0.4927     22601
#
#     accuracy                         0.5202     48493
#    macro avg     0.5189    0.5189    0.5188     48493
# weighted avg     0.5211    0.5202    0.5206     48493

# %%
from sklearn.metrics import f1_score, classification_report, confusion_matrix, roc_auc_score

## Used to Evaluate NN models ##
def evaluate_nn_model(model, X, y, name="Model"):
    prob = model.predict(X, verbose=0).ravel()
    pred = (prob >= 0.5).astype(int)

    print(f"\n{name}")
    print("Accuracy:", round(accuracy_score(y, pred), 4))
    print("F1:", round(f1_score(y, pred, average='macro'), 4))
    print("ROC AUC:", round(roc_auc_score(y, prob), 4))
    print("\nConfusion Matrix")
    print(confusion_matrix(y, pred))
    print("\nClassification Report")
    print(classification_report(y, pred, digits=4))


## Used to Evaluate the Logistic Regression and LightGBM models ##
def evaluate(model, X_test, y_test):
    y_pred = model.predict(X_test)
    probs = model.predict_proba(X_test)[:,1]

    print("Classification Report:\n")
    print(classification_report(y_test, y_pred))
    print("F1:", round(f1_score(y_test, y_pred, average='macro'), 4))
    print("ROC-AUC:", round(roc_auc_score(y_test, probs, average='macro'), 4))


print("Logistic Regression - Standard:")
evaluate(log_reg, X_val, y_val)
print("\n-----  -----  -----  -----  -----  -----  -----  -----  -----  -----")
print("Elastic Net Logistic Regression:")
evaluate(elastic_net, X_val, y_val)
print("\n-----  -----  -----  -----  -----  -----  -----  -----  -----  -----")
print("Weighted Logistic Regression:")
evaluate(weight_log_reg, X_val, y_val)
print("LightGBM Model 1:")
evaluate(lgb_model1, X_val, y_val)
print("\n-----  -----  -----  -----  -----  -----  -----  -----  -----  -----")
print("LightGBM Model 2:")
evaluate(lgb_model2, X_val, y_val)
print("\n-----  -----  -----  -----  -----  -----  -----  -----  -----  -----")
print("LightGBM Model 3:")
evaluate(lgb_model3, X_val, y_val)
print("\n-----  -----  -----  -----  -----  -----  -----  -----  -----  -----")
print("Neural Network Baseline:")
evaluate_nn_model(model_base, X_val_s, y_val_nn, name="NN Baseline")
print("\n-----  -----  -----  -----  -----  -----  -----  -----  -----  -----")
print("Neural Network Regularized:")
evaluate_nn_model(model_reg,X_val_s, y_val_nn, name="NN Regularized")
print("\n-----  -----  -----  -----  -----  -----  -----  -----  -----  -----")
print("Neural Network Regularized Deep:")
evaluate_nn_model(model_reg_deep, X_val_s, y_val_nn, name="NN Regularized Deep")
# Out:
# Logistic Regression - Standard:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.85      0.66     26843
#            1       0.50      0.16      0.24     24118
#
#     accuracy                           0.53     50961
#    macro avg       0.52      0.51      0.45     50961
# weighted avg       0.52      0.53      0.46     50961
#
# F1: 0.45
# ROC-AUC: 0.5143
#
# -----  -----  -----  -----  -----  -----  -----  -----  -----  -----
# Elastic Net Logistic Regression:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.85      0.66     26843
#            1       0.50      0.16      0.24     24118
#
#     accuracy                           0.53     50961
#    macro avg       0.52      0.51      0.45     50961
# weighted avg       0.52      0.53      0.46     50961
#
# F1: 0.4501
# ROC-AUC: 0.5143
#
# -----  -----  -----  -----  -----  -----  -----  -----  -----  -----
# Weighted Logistic Regression:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.66      0.59     26843
#            1       0.49      0.35      0.41     24118
#
#     accuracy                           0.52     50961
#    macro avg       0.51      0.51      0.50     50961
# weighted avg       0.51      0.52      0.51     50961
#
# F1: 0.5008
# ROC-AUC: 0.5143
# LightGBM Model 1:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57     26843
#            1       0.49      0.40      0.44     24118
#
#     accuracy                           0.52     50961
#    macro avg       0.51      0.51      0.51     50961
# weighted avg       0.51      0.52      0.51     50961
#
# F1: 0.5063
# ROC-AUC: 0.5129
#
# -----  -----  -----  -----  -----  -----  -----  -----  -----  -----
# LightGBM Model 2:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.53      0.53     26843
#            1       0.48      0.49      0.48     24118
#
#     accuracy                           0.51     50961
#    macro avg       0.51      0.51      0.51     50961
# weighted avg       0.51      0.51      0.51     50961
#
# F1: 0.5088
# ROC-AUC: 0.5134
#
# -----  -----  -----  -----  -----  -----  -----  -----  -----  -----
# LightGBM Model 3:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.67      0.59     26843
#            1       0.48      0.35      0.41     24118
#
#     accuracy                           0.52     50961
#    macro avg       0.51      0.51      0.50     50961
# weighted avg       0.51      0.52      0.50     50961
#
# F1: 0.4991
# ROC-AUC: 0.5144
#
# -----  -----  -----  -----  -----  -----  -----  -----  -----  -----
# Neural Network Baseline:
#
# NN Baseline
# Accuracy: 0.4994
# F1: 0.4976
# ROC AUC: 0.5045
#
# Confusion Matrix
# [[11208 15635]
#  [ 9878 14240]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0     0.5315    0.4175    0.4677     26843
#            1     0.4767    0.5904    0.5275     24118
#
#     accuracy                         0.4994     50961
#    macro avg     0.5041    0.5040    0.4976     50961
# weighted avg     0.5056    0.4994    0.4960     50961
#
#
# -----  -----  -----  -----  -----  -----  -----  -----  -----  -----
# Neural Network Regularized:
#
# NN Regularized
# Accuracy: 0.4919
# F1: 0.4877
# ROC AUC: 0.4991
#
# Confusion Matrix
# [[10225 16618]
#  [ 9275 14843]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0     0.5244    0.3809    0.4413     26843
#            1     0.4718    0.6154    0.5341     24118
#
#     accuracy                         0.4919     50961
#    macro avg     0.4981    0.4982    0.4877     50961
# weighted avg     0.4995    0.4919    0.4852     50961
#
#
# -----  -----  -----  -----  -----  -----  -----  -----  -----  -----
# Neural Network Regularized Deep:
#
# NN Regularized Deep
# Accuracy: 0.5012
# F1: 0.4983
# ROC AUC: 0.4995
#
# Confusion Matrix
# [[14695 12148]
#  [13273 10845]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0     0.5254    0.5474    0.5362     26843
#            1     0.4717    0.4497    0.4604     24118
#
#     accuracy                         0.5012     50961
#    macro avg     0.4985    0.4986    0.4983     50961
# weighted avg     0.5000    0.5012    0.5003     50961

# %%
def evaluate_to_df(model, X_test, y_test, model_name):
    y_pred = model.predict(X_test)
    probs = model.predict_proba(X_test)[:, 1]

    # Classification report as table
    report_dict = classification_report(y_test, y_pred, output_dict=True)
    report_df = pd.DataFrame(report_dict).T

    # Add summary metrics
    report_df.loc["overall", "f1_marco"] = f1_score(y_test, y_pred, average='macro')
    report_df.loc["overall", "roc_auc"] = roc_auc_score(y_test, probs, average='macro')
    report_df["model"] = model_name

    return report_df

results = {
    "Logistic Regression": evaluate_to_df(log_reg, X_val, y_val, "Logistic Regression"),
    "Elastic Net Logistic Regression": evaluate_to_df(elastic_net, X_val, y_val, "Elastic Net Logistic Regression"),
    "Weighted Logistic Regression": evaluate_to_df(weight_log_reg, X_val, y_val, "Weighted Logistic Regression"),
    "LightGBM Model 1": evaluate_to_df(lgb_model1, X_val, y_val, "LightGBM Model 1"),
    "LightGBM Model 2": evaluate_to_df(lgb_model2, X_val, y_val, "LightGBM Model 2"),
    "LightGBM Model 3": evaluate_to_df(lgb_model3, X_val, y_val, "LightGBM Model 3"),
}

## THIS NEEDS TO BE UPDATED TO GITHUB OUTPUT PATH
class_report_output = r"/Users/christoomey/Desktop/Courses/ADAN8888_Applied_Analytics_Project/Output/classification_reports_week09.xlsx"

# one sheet per model
with pd.ExcelWriter(class_report_output, engine="openpyxl") as writer:
    for sheet_name, df in results.items():
        df.to_excel(writer, sheet_name=sheet_name)

print(f"Saved to {class_report_output}")
# Out:
# Saved to /Users/christoomey/Desktop/Courses/ADAN8888_Applied_Analytics_Project/Output/classification_reports_week09.xlsx

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

models = {
    "Logistic Regression": log_reg,
    "Elastic Net Logistic Regression": elastic_net,
    "Weighted Logistic Regression": weight_log_reg,
    "LightGBM Model 1": lgb_model1,
    "LightGBM Model 2": lgb_model2,
    "LightGBM Model 3": lgb_model3
}

# Create confusion matrix tables
cm_tables = {}
for name, model in models.items():

    y_pred = model.predict(X_val)
    cm = confusion_matrix(y_val, y_pred)  # [[TN, FP], [FN, TP]]
    cm_df = pd.DataFrame(cm,
                         index=["Actual 0", "Actual 1"],
                         columns=["Pred 0", "Pred 1"])
    cm_tables[name] = cm_df
    print(f"\n{name}\n{cm_df}")
    
# Plot confusion matrix for each model
fig, axes = plt.subplots(2, 3, figsize=(15, 8))

for ax, (name, model) in zip(axes.flat, models.items()):
    y_pred = model.predict(X_val)
    ConfusionMatrixDisplay.from_predictions(
        y_val, y_pred, ax=ax, cmap="Blues", values_format="d"
    )
    ax.set_title(name)

plt.tight_layout()
plt.show()
# Out:
# Logistic Regression
#           Pred 0  Pred 1
# Actual 0   22947    3896
# Actual 1   20216    3902
#
# Elastic Net Logistic Regression
#           Pred 0  Pred 1
# Actual 0   22949    3894
# Actual 1   20216    3902
#
# Weighted Logistic Regression
#           Pred 0  Pred 1
# Actual 0   17813    9030
# Actual 1   15571    8547
#
# LightGBM Model 1
#           Pred 0  Pred 1
# Actual 0   16670   10173
# Actual 1   14505    9613
#
# LightGBM Model 2
#           Pred 0  Pred 1
# Actual 0   14245   12598
# Actual 1   12372   11746
#
# LightGBM Model 3
#           Pred 0  Pred 1
# Actual 0   17880    8963
# Actual 1   15685    8433

# %%
# Selected the best model from validation performance and evaluate on test set
#print("\n-----  -----  -----  -----  -----  -----  -----  -----  -----  -----")
#print("LightGBM Model 2 - Test Set:")
#evaluate(model2, X_test, y_test)
