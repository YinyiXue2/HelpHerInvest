# %%
#%pip install openai python-dotenv
#%pip install -qU langchain-openai langchain
#%pip install langchain_community pyowm
#%pip install --upgrade --quiet  youtube_search
# Out:
# Requirement already satisfied: openai in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.86.0)
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (2.11.6)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3.13 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3.13 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain_community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pyowm
#   Downloading pyowm-3.5.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langchain_community) (1.2.18)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Downloading langchain_classic-1.0.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Downloading sqlalchemy-2.0.48-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting requests<3.0.0,>=2.32.5 (from langchain_community)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langchain_community) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Downloading aiohttp-3.13.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langchain_community) (9.1.4)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Downloading pydantic_settings-2.13.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langchain_community) (0.7.16)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langchain_community) (2.2.4)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading frozenlist-1.8.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading multidict-6.7.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading propcache-0.4.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading yarl-1.23.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.11.6)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /Users/tongyuguo/Library/Python/3.13/lib/python/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.13.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.10)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.4.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting geojson<4,>=2.3.0 (from pyowm)
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Collecting PySocks<2,>=1.7.1 (from pyowm)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 20.1 MB/s  0:00:00
# Downloading aiohttp-3.13.3-cp313-cp313-macosx_11_0_arm64.whl (490 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.2-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.4 MB/s  0:00:00
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp313-cp313-macosx_11_0_arm64.whl (43 kB)
# Downloading pydantic_settings-2.13.1-py3-none-any.whl (58 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading sqlalchemy-2.0.48-cp313-cp313-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 18.9 MB/s  0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.23.0-cp313-cp313-macosx_11_0_arm64.whl (85 kB)
# Downloading pyowm-3.5.0-py3-none-any.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 13.6 MB/s  0:00:00 eta 0:00:01
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-macosx_11_0_arm64.whl (49 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading propcache-0.4.1-cp313-cp313-macosx_11_0_arm64.whl (46 kB)
# Installing collected packages: SQLAlchemy, requests, PySocks, propcache, mypy-extensions, multidict, marshmallow, httpx-sse, geojson, frozenlist, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pyowm, pydantic-settings, dataclasses-json, aiohttp, langchain-text-splitters, langchain-classic, langchain_community
#   Attempting uninstall: requests━━━━━━━━━━━━━━━━  0/21 [SQLAlchemy]
#     Found existing installation: requests 2.32.3  0/21 [SQLAlchemy]
#     Uninstalling requests-2.32.3:━━━━━━━━━━━  0/21 [SQLAlchemy]
#       Successfully uninstalled requests-2.32.30m  0/21 [SQLAlchemy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21/21 [langchain_community]ngchain_community]
# Successfully installed PySocks-1.7.1 SQLAlchemy-2.0.48 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 dataclasses-json-0.6.7 frozenlist-1.8.0 geojson-3.2.0 httpx-sse-0.4.3 langchain-classic-1.0.2 langchain-text-splitters-1.1.1 langchain_community-0.4.1 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 propcache-0.4.1 pydantic-settings-2.13.1 pyowm-3.5.0 requests-2.32.5 typing-inspect-0.9.0 yarl-1.23.0
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3.13 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3.13 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pprint import pprint

#API 
from dotenv import load_dotenv
import os
load_dotenv() 

'''

# Using LongChain to Connect OpenAI
from langchain_openai import ChatOpenAI
openAIModel = ChatOpenAI(model="gpt-4o-mini")
from langchain_core.messages import HumanMessage, SystemMessage

# LongChain Agents
from langchain.agents import AgentType, initialize_agent, load_tools
'''
# Out:
# '\n\n# Using LongChain to Connect OpenAI\nfrom langchain_openai import ChatOpenAI\nopenAIModel = ChatOpenAI(model="gpt-4o-mini")\nfrom langchain_core.messages import HumanMessage, SystemMessage\n\n# LongChain Agents\nfrom langchain.agents import AgentType, initialize_agent, load_tools\n'

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.4",
    input="Write a one-sentence bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# Under a blanket of twinkling stars, a gentle unicorn tiptoed through the moonlit meadow, sprinkling sleepy silver dreams over every flower before curling up beneath a glowing willow tree.

# %%
from openai import OpenAI
client = OpenAI()

file = client.files.create(
    file=open("nlp_clean_stock_symbols.csv", "rb"),
    purpose="user_data"
)

response = client.responses.create(
    model="gpt-5-mini",
    input=[
        {
            "role": "user",
            "content": [
                {
                    "type": "input_file",
                    "file_id": file.id,
                },
                {
                    "type": "input_text",
                    "text": "Role: you are a data scientist in charge of filtering out stock symbels that is relevant to user input. Input: I like dessert food. Steps: you first analyze user input, then select relevant symbbols from file located in https://github.com/tongyuguo/HelpHerInvest/blob/main/Data/nlp_clean_stock_symbols.csv. Expectation: you are expected to return a list of 20 relebant stock symbosl given user imput.",
                },
            ]
        }
    ]
)

print(response.output_text)
# Out:
# Analysis: "I like dessert food" points to companies in the dataset that make or sell desserts/snacks/ice‑cream, beverages often paired with desserts, grocery & club retailers that sell dessert items, food e‑commerce platforms, restaurants/entertainment venues that sell desserts, and logistic/real‑estate/energy firms that support food distribution.
#
# From the CSV, here are 20 symbols relevant to "dessert food" (picked because their business descriptions mention food/beverages, ice cream/snacks, restaurants, grocery/e‑commerce, or direct support to food distribution/retail):
#
# 1. PEP (PepsiCo)
# 2. KO (Coca‑Cola)
# 3. UL (Unilever PLC)
# 4. MCD (McDonald's)
# 5. WMT (Walmart)
# 6. COST (Costco Wholesale)
# 7. AMZN (Amazon.com)
# 8. BABA (Alibaba Group)
# 9. PDD (PDD Holdings / Pinduoduo / Temu)
# 10. DIS (Walt Disney Co — parks & venues with food/desserts)
# 11. BUD (Anheuser‑Busch InBev — beverages)
# 12. ABT (Abbott Laboratories — nutritional / infant & nutritional products)
# 13. BKNG (Booking Holdings — OpenTable / restaurant reservations)
# 14. PLD (Prologis — logistics/warehouse real estate for grocery / food e‑commerce)
# 15. PG (Procter & Gamble — large consumer goods/retail presence)
# 16. WELL (Welltower — senior housing / hospitality where food is important)
# 17. CEG (Constellation Energy — energy for food production/processing & retail operations)
# 18. SHEL (Shell plc — fuel/energy supporting distribution & retail logistics)
# 19. AMAT (Applied Materials) — (included as a supply‑chain/logistics adjacent pick for food tech manufacturers)
# 20. BABA / PDD / AMZN already listed — if you prefer a closer food company replacement for overlap, consider: UL (already listed) or add PLTR (Palantir) only if you want data/analytics providers used by big food retailers.
#
# If you'd like, I can:
# - narrow to only pure food & beverage producers and retailers (no logistics/energy/support firms), or
# - return detailed company descriptions from the CSV for each chosen symbol so you can inspect why I picked them.
