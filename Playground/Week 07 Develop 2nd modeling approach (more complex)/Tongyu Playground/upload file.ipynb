# %%
from pprint import pprint

#API 
from dotenv import load_dotenv
import os
load_dotenv() 


from openai import OpenAI
client = OpenAI()

client.files.create(
  file=open("mydata.jsonl", "rb"),
  purpose="fine-tune",
  expires_after={
    "anchor": "created_at",
    "seconds": 2592000
  }
)

# %%
from pprint import pprint

#API 
from dotenv import load_dotenv
import os
load_dotenv() 

from openai import OpenAI

client = OpenAI()

file = client.files.create(
file=open("nlp_clean_stock_symbols.csv", "rb"),
purpose="user_data" # or "fine-tune"
)

print(file.id)
# Out:
# file-Uwm8MRkzZj3RExEy1MwyV8
